# %% [markdown]
# # 🔧 Python周末练习 - 自己动手填空
# **规则**：所有代码单元格都有**下划线标记的空缺**，需要你自己写代码填补
# **创建时间**：2026-01-31
#
# ## 📋 使用说明
#
# 1. 每个代码单元格都有 `___` 标记的需要填补的地方
# 2. **先自己思考**怎么写代码
# 3. 删除 `___`，写上你的代码
# 4. 运行单元格检查是否正确
#
# ## ⚠️ 重要提示
# - 不要直接看答案，先自己尝试
# - 可以添加新的单元格练习
# - 遇到困难可以先画流程图

# %% [markdown]
# # 第一部分：基础回顾
#
# 巩固已学知识

# %% [markdown]
# ## 练习1：列表操作填空
#
# 完成以下列表操作：

# %%
# 任务：创建一个购物清单，并进行操作

# 1. 创建一个包含3个商品的列表
shopping_list = ["苹果","牛奶","面包"]  # 填入你的代码，例如：["苹果", "牛奶", "面包"]
print("1. 购物清单:", shopping_list)

# 2. 在列表末尾添加一个新商品
shopping_list.append("鸡蛋")  # 填入代码：添加"鸡蛋"到列表
print("2. 添加鸡蛋后:", shopping_list)

# 3. 修改第二个商品为"酸奶"
shopping_list[1] = "酸奶"  # 填入代码：修改索引1的元素
print("3. 修改后:", shopping_list)

# 4. 删除第三个商品
del shopping_list[2]  # 填入代码：删除索引2的元素
print("4. 删除后:", shopping_list)

# 5. 使用for循环打印每个商品
print("5. 遍历商品:")
for each in shopping_list:
    print(each,end=" ")  # 填入for循环代码

print("\n" + "="*50)
# Out:
# 1. 购物清单: ['苹果', '牛奶', '面包']
# 2. 添加鸡蛋后: ['苹果', '牛奶', '面包', '鸡蛋']
# 3. 修改后: ['苹果', '酸奶', '面包', '鸡蛋']
# 4. 删除后: ['苹果', '酸奶', '鸡蛋']
# 5. 遍历商品:
# 苹果 酸奶 鸡蛋
# ...

# %% [markdown]
# ## 练习2：字符串操作填空
#
# 完成以下字符串操作：

# %%
# 任务：处理一段文本

text = "Python编程很有趣，我每天都学习Python"

# 1. 获取字符串长度
length = len(text)  # 填入代码
print("1. 字符串长度:", length)

# 2. 统计"Python"出现的次数
# 提示：使用count()方法
python_count = text.count("Python")  # 填入代码
print("2. 'Python'出现次数:", python_count)

# 3. 将字符串中的所有"Python"替换为"编程"
new_text = text.replace("Python","编程")  # 填入代码
print("3. 替换后:", new_text)

# 4. 检查字符串是否以"Python"开头
starts_with_python = text.startswith("Python")  # 填入代码
print("4. 以'Python'开头:", starts_with_python)
# Out:
# 1. 字符串长度: 24
# 2. 'Python'出现次数: 2
# 3. 替换后: 编程编程很有趣，我每天都学习编程
# 4. 以'Python'开头: True

# %%
# 练习3：循环和条件填空

# 任务：找出1-100之间能被7整除的数

# 1. 创建一个空列表存储结果
divisible_by_7 = []

# 2. 使用for循环遍历1-100
for i in range(1,101):  # 填入循环代码
    # 3. 判断是否能被7整除
    if i%7 == 0:  # 填入条件判断代码
        # 4. 如果能被整除，添加到列表
        divisible_by_7.append(i)  # 填入添加代码

print("1-100之间能被7整除的数:")
print(divisible_by_7)
print(f"共有{len(divisible_by_7)}个")

# 进阶：计算这些数的总和
total = 0
for j in divisible_by_7:
    total += j  # 填入计算总和的循环代码

print(f"这些数的总和是: {total}")
# Out:
# 1-100之间能被7整除的数:
# [7, 14, 21, 28, 35, 42, 49, 56, 63, 70, 77, 84, 91, 98]
# 共有14个
# 这些数的总和是: 735

# %% [markdown]
# # 第二部分：字典专项练习
#
# 本周新学：字典

# %%
# 练习4：字典创建填空

# 1. 创建一个空字典
empty_dict = {}  # 填入创建空字典的代码
print("1. 空字典:", empty_dict)

# 2. 创建一个学生字典，包含姓名、年龄、成绩
student = {
    "姓名": "张三",  # 填入姓名
    "年龄": 15,  # 填入年龄
    "成绩": 90   # 填入成绩
}
print("2. 学生字典:", student)

# 3. 使用两个列表创建字典（不使用zip）
keys = ["语文", "数学", "英语"]
values = [85, 90, 88]

subject_scores = {}
for i in range(len(keys)):
    # 将keys[i]和values[i]添加到字典中
    subject_scores[keys[i]] = values[i]  # 填入代码

print("3. 科目成绩字典:", subject_scores)

# 4. 使用zip创建字典（复习上周内容）
countries = ["中国", "美国", "日本"]
capitals = ["北京", "华盛顿", "东京"]

country_capital = {}
for country, capital in zip(countries, capitals):
    # 将country作为键，capital作为值添加到字典
    country_capital[country] = capital  # 填入代码

print("4. 国家首都字典:", country_capital)
# Out:
# 1. 空字典: {}
# 2. 学生字典: {'姓名': '张三', '年龄': 15, '成绩': 90}
# 3. 科目成绩字典: {'语文': 85, '数学': 90, '英语': 88}
# 4. 国家首都字典: {'中国': '北京', '美国': '华盛顿', '日本': '东京'}

# %%
# 练习5：字典访问和修改填空

# 给定一个商品字典
product = {
    "name": "笔记本电脑",
    "brand": "联想",
    "price": 5999,
    "stock": 50
}

print("原始商品信息:", product)

# 1. 获取商品名称
product_name = product['name']  # 填入访问代码
print("\n1. 商品名称:", product_name)

# 2. 使用get方法获取颜色，如果不存在返回"黑色"
product_color = product.get("color","黑色")  # 填入get方法代码
print("2. 商品颜色:", product_color)

# 3. 修改商品价格为5499
product["price"] = 5499  # 填入修改代码
print("3. 修改后价格:", product["price"])

# 4. 添加新信息：重量"2.5kg"
product["weight"] = "2.5kg"  # 填入添加代码
print("4. 添加重量后:", product)

# 5. 删除库存信息
del product["stock"]  # 填入删除代码
print("5. 删除库存后:", product)

# 6. 检查"brand"键是否存在
has_brand = "brand" in product  # 填入检查代码
print("6. 包含'brand':", has_brand)
# Out:
# 原始商品信息: {'name': '笔记本电脑', 'brand': '联想', 'price': 5999, 'stock': 50}
#
# 1. 商品名称: 笔记本电脑
# 2. 商品颜色: 黑色
# 3. 修改后价格: 5499
# 4. 添加重量后: {'name': '笔记本电脑', 'brand': '联想', 'price': 5499, 'stock': 50, 'weight': '2.5kg'}
# 5. 删除库存后: {'name': '笔记本电脑', 'brand': '联想', 'price': 5499, 'weight': '2.5kg'}
# 6. 包含'brand': True

# %%
# 练习6：字典遍历填空

student_scores = {
    "张三": 85,
    "李四": 92,
    "王五": 78,
    "赵六": 95
}

print("学生成绩字典:", student_scores)

# 1. 遍历所有键（学生姓名）
print("\n1. 所有学生姓名:")
for name in student_scores:
    print(name,end=" ")  # 填入打印代码

# 2. 遍历所有值（成绩）
print("\n2. 所有成绩:")
for score in student_scores.values():
    print(score,end=" ")  # 填入打印代码

# 3. 遍历键值对，打印"姓名: 成绩"格式
print("\n3. 学生姓名和成绩:")
for name, score in student_scores.items():
    print(f"{name}:{score}")  # 填入打印代码

# 4. 计算平均成绩
total_score = 0
student_count = 0

for name in student_scores:  # 填入计算总成绩和学生人数的循环代码
    student_count += 1
for score in student_scores.values():
    total_score += score
average_score = total_score / student_count if student_count > 0 else 0
print(f"\n4. 平均成绩: {average_score:.2f}")

# 5. 找出最高分和对应的学生
highest_score = 0
top_student = ""

for score in student_scores.values():  # 填入查找最高分的循环代码
    if score > highest_score:
        highest_score = score
for name in student_scores:
    if student_scores[name] == highest_score:
        top_student = name
print(f"5. 最高分: {top_student} ({highest_score}分)")
# Out:
# 学生成绩字典: {'张三': 85, '李四': 92, '王五': 78, '赵六': 95}
#
# 1. 所有学生姓名:
# 张三 李四 王五 赵六
# 2. 所有成绩:
# 85 92 78 95
# 3. 学生姓名和成绩:
# 张三:85
# 李四:92
# 王五:78
# 赵六:95
#
# 4. 平均成绩: 87.50
# 5. 最高分: 赵六 (95分)

# %%
# 练习7：字典与列表结合填空

# 场景：多个学生，每个学生有多门课程成绩
students_grades = {
    "张三": [85, 90, 88],  # 语文、数学、英语
    "李四": [92, 85, 91],
    "王五": [78, 88, 85]
}

# 1. 计算每个学生的总分
print("1. 学生总分:")
for name, grades in students_grades.items():
    total = 0
    ___  # 填入计算总分的循环代码
    print(f"  {name}: {total}分")

# 2. 计算每个学生的平均分
print("\n2. 学生平均分:")
for name, grades in students_grades.items():
    total = 0
    count = 0
    ___  # 填入计算总分和科目数的代码
    average = total / count if count > 0 else 0
    print(f"  {name}: {average:.1f}分")

# 3. 找出每门课的最高分学生
print("\n3. 各科最高分:")
course_names = ["语文", "数学", "英语"]

for course_index in range(3):  # 三门课
    max_score = 0
    top_student = ""
    
    ___  # 填入查找每门课最高分的循环代码
    
    print(f"  {course_names[course_index]}: {top_student} ({max_score}分)")

# %% [markdown]
# # 第三部分：综合填空项目
#
# 完成两个实际项目

# %% [markdown]
# ## 项目1：简易电话簿系统
#
# 完成下面的电话簿代码：

# %%
# 项目1：简易电话簿系统

# 初始化电话簿
phone_book = {
    "张三": "13800138000",
    "李四": "13900139000"
}

print("=== 简易电话簿管理系统 ===")

# 主循环
while True:
    print("\n当前电话簿联系人:")
    if len(phone_book) == 0:
        print("  (空)")
    else:
        for name, phone in phone_book.items():
            print(f"  {name}: {phone}")
    
    print("\n请选择操作:")
    print("  1. 添加联系人")
    print("  2. 查找联系人")
    print("  3. 修改联系人电话")
    print("  4. 删除联系人")
    print("  5. 退出系统")
    
    choice = input("请输入选项(1-5): ")
    
    if choice == "1":
        # 添加联系人
        name = input("请输入联系人姓名: ")
        if name in phone_book:
            print(f"联系人'{name}'已存在，电话是: {phone_book[name]}")
        else:
            phone = input("请输入电话号码: ")
            # 将联系人添加到电话簿
            ___  # 填入添加代码
            print(f"已添加联系人: {name}")
    
    elif choice == "2":
        # 查找联系人
        name = input("请输入要查找的联系人姓名: ")
        if name in phone_book:
            # 打印联系人的电话号码
            ___  # 填入打印代码
        else:
            print(f"未找到联系人: {name}")
    
    elif choice == "3":
        # 修改联系人电话
        name = input("请输入要修改的联系人姓名: ")
        if name in phone_book:
            new_phone = input(f"请输入'{name}'的新电话号码: ")
            # 更新电话号码
            ___  # 填入更新代码
            print(f"已更新联系人: {name}")
        else:
            print(f"未找到联系人: {name}")
    
    elif choice == "4":
        # 删除联系人
        name = input("请输入要删除的联系人姓名: ")
        if name in phone_book:
            confirm = input(f"确认删除'{name}'吗?(Y/N): ")
            if confirm.lower() == "y":
                # 删除联系人
                ___  # 填入删除代码
                print(f"已删除联系人: {name}")
            else:
                print("取消删除")
        else:
            print(f"未找到联系人: {name}")
    
    elif choice == "5":
        # 退出系统
        print("感谢使用电话簿，再见！")
        ___  # 填入退出循环的代码
    
    else:
        print("无效选项，请重新输入！")

# %% [markdown]
# ## 项目2：单词频率统计器
#
# 完成下面的单词统计代码：

# %%
# 项目2：单词频率统计器

# 示例文本
text = "python is easy python is powerful python is fun"

print("原文:")
print(f"  '{text}'")

# 1. 将文本分割成单词列表
words = ___  # 填入分割代码
print(f"\n1. 单词列表: {words}")

# 2. 统计每个单词出现的次数
word_count = {}  # 创建空字典

for word in words:
    if word in word_count:
        # 如果单词已存在，次数加1
        ___  # 填入代码
    else:
        # 如果单词不存在，初始化为1
        ___  # 填入代码

print("\n2. 单词出现次数:")
for word, count in word_count.items():
    print(f"  {word}: {count}次")

# 3. 找出出现最多的单词
max_count = 0
most_common_word = ""

for word, count in word_count.items():
    # 找出出现次数最多的单词
    ___  # 填入比较和赋值的代码

print(f"\n3. 出现最多的单词: '{most_common_word}' ({max_count}次)")

# 4. 进阶：处理带标点的文本
print("\n4. 进阶挑战：处理带标点的文本")

text_with_punctuation = "Python, is a powerful language. Python is easy! Python is fun."
print(f"\n带标点的文本: '{text_with_punctuation}'")

# 清洗文本：去除标点，转为小写
clean_words = []
current_word = ""

for char in text_with_punctuation:
    if char.isalpha():  # 如果是字母
        # 将字母添加到当前单词，并转为小写
        ___  # 填入代码
    elif current_word:  # 如果不是字母且current_word不为空
        # 将当前单词添加到列表
        ___  # 填入代码
        current_word = ""  # 重置当前单词

# 处理最后一个单词
if current_word:
    clean_words.append(current_word)

print(f"清洗后的单词: {clean_words}")

# %% [markdown]
# # 🏆 第四部分：挑战题
#
# 如果你完成了前面的所有填空，试试这些挑战题：
#
# ## 挑战1：学生成绩管理系统
#
# 创建一个学生成绩管理系统，需要存储：
# - 学生姓名
# - 年龄
# - 三门课程成绩（语文、数学、英语）
#
# **要求**：
# 1. 使用字典嵌套字典的结构
# 2. 实现添加、查询、删除功能
# 3. 计算每个学生的平均分
# 4. 找出每门课的最高分学生
#
# **数据结构提示**：
# ```python
# students = {
#     "张三": {"年龄": 18, "成绩": [85, 90, 88]},
#     "李四": {"年龄": 19, "成绩": [92, 85, 91]}
# }
# ```
#
# ## 挑战2：购物车系统
#
# 创建一个简单的购物车系统：
#
# **商品信息**：
# ```python
# products = {
#     "苹果": {"价格": 5.5, "库存": 100},
#     "香蕉": {"价格": 3.2, "库存": 50},
#     "橙子": {"价格": 4.8, "库存": 80}
# }
# ```
#
# **购物车**：
# ```python
# cart = {"苹果": 2, "香蕉": 3}  # 商品名: 数量
# ```
#
# **要求**：
# 1. 显示所有商品
# 2. 将商品加入购物车
# 3. 从购物车移除商品
# 4. 计算购物车总价
# 5. 结账（减少库存）
#
# ---
#
# ## 📝 我的解决方案
#
# 在下面单元格中写下你的挑战题解决方案：

# %%
# 在这里写下挑战题的解决方案

# 挑战1：学生成绩管理系统

# 你的代码开始



# 挑战2：购物车系统

# 你的代码开始

# %% [markdown]
# # 📚 第五部分：学习总结与反思
#
# 完成练习后，填写以下总结：
#
# ## ✅ 完成情况
# - [ ] 第一部分：基础回顾填空
# - [ ] 第二部分：字典专项填空
# - [ ] 第三部分：综合填空项目
# - [ ] 第四部分：挑战题
#
# ## 🎓 我学到的关键知识
#
# 1.
# 2.
# 3.
#
# ## ❌ 我卡住的地方
#
# 1.
# 2.
#
# ## 💡 我发现的技巧
#
# ```python
# # 我发现的实用代码片段
#
# ```
#
# ## 📈 我的进步
#
# （写下你感觉有进步的方面）
#
# ## 🎯 下一步学习目标
#
# 1.
# 2.
# 3.

# %% [markdown]
# # 🔍 参考答案（先自己尝试！）
#
# <details>
# <summary>点击展开查看答案（建议先自己尝试）</summary>
#
# ## 练习1：列表操作
# ```python
# shopping_list = ["苹果", "牛奶", "面包"]
# shopping_list.append("鸡蛋")
# shopping_list[1] = "酸奶"
# del shopping_list[2]
# for item in shopping_list:
#     print(f"  {item}")
# ```
#
# ## 练习2：字符串操作
# ```python
# length = len(text)
# python_count = text.count("Python")
# new_text = text.replace("Python", "编程")
# starts_with_python = text.startswith("Python")
# ```
#
# ## 练习3：循环和条件
# ```python
# for i in range(1, 101):
#     if i % 7 == 0:
#         divisible_by_7.append(i)
#
# for num in divisible_by_7:
#     total += num
# ```
#
# ## 练习4：字典创建
# ```python
# empty_dict = {}
# student = {"姓名": "张三", "年龄": 18, "成绩": 85}
# subject_scores[keys[i]] = values[i]
# country_capital[country] = capital
# ```
#
# ## 练习5：字典访问
# ```python
# product_name = product["name"]
# product_color = product.get("color", "黑色")
# product["price"] = 5499
# product["weight"] = "2.5kg"
# del product["stock"]
# has_brand = "brand" in product
# ```
#
# ## 练习6：字典遍历
# ```python
# for name in student_scores:
#     print(f"  {name}")
#
# for score in student_scores.values():
#     print(f"  {score}")
#
# for name, score in student_scores.items():
#     print(f"  {name}: {score}")
#
# for score in student_scores.values():
#     total_score += score
#     student_count += 1
#
# for name, score in student_scores.items():
#     if score > highest_score:
#         highest_score = score
#         top_student = name
# ```
#
# ## 练习7：字典与列表结合
# ```python
# for grade in grades:
#     total += grade
#
# for grade in grades:
#     total += grade
#     count += 1
#
# for name, grades in students_grades.items():
#     if grades[course_index] > max_score:
#         max_score = grades[course_index]
#         top_student = name
# ```
#
# ## 项目1：电话簿
# ```python
# phone_book[name] = phone
# print(f"{name}: {phone_book[name]}")
# phone_book[name] = new_phone
# del phone_book[name]
# break
# ```
#
# ## 项目2：单词统计
# ```python
# words = text.split()
# word_count[word] += 1
# word_count[word] = 1
# if count > max_count:
#     max_count = count
#     most_common_word = word
# current_word += char.lower()
# clean_words.append(current_word)
# ```
#
# </details>
