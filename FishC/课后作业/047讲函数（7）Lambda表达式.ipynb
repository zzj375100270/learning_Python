# %% [markdown]
# 0. 请使用 lambda 表达式和 filter() 函数配合，替换下面代码清单中的 for 循环。

# %%
power = {"吕布":999, "关羽":888, "刘备":666, "张飞":900, "赵云":789, "不二如是":999}
# 请 lambda 表达式和 filter() 函数配合，替换下面的代码
greater = []
for k, v in power.items():
    if v > 800:
        greater.append((k,v))
# 请 lambda 表达式和 filter() 函数配合，替换下面的代码    
print(greater)
[('吕布', 999), ('关羽', 888), ('张飞', 900), ('不二如是', 999)]

# %%
greater = list(filter((lambda x : x[1] > 800), power.items()))

# %% [markdown]
# 1. 请用一行代码找出猪队友。
# 请使用一行代码，找到每个队伍的 “猪队友”（给大家降低一点难度，我们假设同一团队中，每位成员的得分均不相同）。
# 团队成员得分最低的，我们尊称其为 “猪队友”

# %%
members = {
    "鱼C工作室" : {"小甲鱼":83, "不二如是":89, "二师兄":64, "小师妹":75, "鱼小二":96},
    "复仇者联盟" : {"钢铁侠":85, "绿巨人":39, "黑寡妇":82, "鹰眼":73, "雷神":99},
    "奥特曼家族" : {"迪迦":99, "艾斯":84, "泰罗":63, "佐菲":78, "赛文":78}}
x = []
print(x)
['鱼C工作室:二师兄', '复仇者联盟:绿巨人', '奥特曼家族:泰罗']

# %%
members = {
    "鱼C工作室" : {"小甲鱼":83, "不二如是":89, "二师兄":64, "小师妹":75, "鱼小二":96},
    "复仇者联盟" : {"钢铁侠":85, "绿巨人":39, "黑寡妇":82, "鹰眼":73, "雷神":99},
    "奥特曼家族" : {"迪迦":99, "艾斯":84, "泰罗":63, "佐菲":78, "赛文":78}}
x = list(map(lambda group:f"{group}:{min(members[group],key=lambda name:members[group][name])}",members))
print(x)
