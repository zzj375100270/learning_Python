# %%
#035讲课后作业0
x = [1,2,0]
for each in x:
    if each:
        print(True)
        break
else:
    print(False)
# Out:
# True

# %%
y = ['a','b','c']
emu = []
for i in range(len(y)):
    emu.append((i,y[i]))
print(emu)
# Out:
# [(0, 'a'), (1, 'b'), (2, 'c')]

# %%
a = [1,2,3]
b = ['a','b','c']
j = 0
zipped = []
while j < len(a) and j < len (b):
    zipped.append((a[j],b[j]))
    j += 1
print(zipped)
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c')]
