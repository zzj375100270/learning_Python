# %% [markdown]
# #053讲永久存储（1）课后习题

# %%
source = r"D:\桌面\Python\learning_Python\FishC\FishC.txt"
target = r"D:\桌面\Python\learning_Python\FishC\FishD.txt"
f = open(source,"r")
f.seek(9)
words = f.read(6)
f.close()
f = open(target,"w")
f.write(words)
f.close()

# %%
source = r"D:\桌面\Python\learning_Python\FishC\FishC.txt"
f = open(source,"r+")
f.truncate(15)
f.close()

# %%
source = r"D:\桌面\Python\learning_Python\FishC\target.zip"
target = r"D:\桌面\Python\learning_Python\FishC\test.jpg"
f = open(source,"rb")
info = f.read()
f.close()
f = open(target,"ab")
f.write(info)
f.close()
