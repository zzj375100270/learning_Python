# %% [markdown]
# #045讲函数（5）闭包课后作业1
# 请设计一个闭包函数，它的功能是每次调用返回一个斐波那契数列

# %%
def fib():
    a = 0
    b = 1
    def cal():
        nonlocal a,b
        print(a)
        a,b = b,a + b      
    return cal
f = fib()
